# %% [markdown]
# # DIME study data analysis using machine learning

# %% [markdown]
# ## Loading the data
#
# The data is loaded using metagenomics MGnify API. Two collections are loaded, one which contains participant information and another that contains the biome expression information.

# %%
import urllib.request
import json

STUDY_ID = "MGYS00006076" # DIME study

analyses_url = f"https://www.ebi.ac.uk/metagenomics/api/v1/studies/{STUDY_ID}?include=analyses&format=json"
samples_url = f"https://www.ebi.ac.uk/metagenomics/api/v1/studies/{STUDY_ID}?include=samples&format=json"

with urllib.request.urlopen(analyses_url) as f:
    analyses = json.load(f)

with urllib.request.urlopen(samples_url) as f:
    samples = json.load(f)

# %% [markdown]
# The participant and biome expression information are stored under different ids, so they must be collated using the infromation from the MGnify data.

# %%
# Participant and expression information are available in two different locations, under different ids
# We use the samples and analyses data to join the two information sources.

biosample_descs = {b['id']: (b['attributes']['sample-name'].upper(), b['attributes']['biosample']) for b in samples['included']}

mg_ids = {
    biosample_descs[m['relationships']['sample']['data']['id']]: m['id'] for m in analyses['included']
}

# %% [markdown]
# We prepare two tables, one which collects the participant information and one which collects biome expression information. The biome expression information is collected usint the [Biosamples](https://www.ebi.ac.uk/biosamples/) API.
#
# They are connected using the DIME study measurement point signifier, e.g., `03-MP`, where `03` refers to the participant number and `MP` refers to the midpoint measurement.

# %%
# The individual expression samples and participant information are loaded and collected in two tables

rows_expression = {}
rows_participant = {}

for (sample_name, bio_id), sample_id in mg_ids.items():

    with urllib.request.urlopen(f"https://www.ebi.ac.uk/metagenomics/api/v1/analyses/{sample_id}/taxonomy/ssu?format=json") as r:
        d = json.loads(r.read())
    
    rows_expression[sample_name] = {
            o['id'].replace('::', ':'): o['attributes']['count'] for o in d['data']
        }
    
    with urllib.request.urlopen(f"https://www.ebi.ac.uk/biosamples/samples/{bio_id}.json") as r:
        bio = json.loads(r.read())
        
    s = bio['characteristics']['host sex'][0]['text'][0].upper()
    a = int(bio['characteristics']['host age'][0]['text'])
    d = '_'.join(bio['characteristics']['host diet'][0]['text'].lower().split(' ')[:2])
    
    rows_participant[sample_name] = {
        'age': a,
        'gender': s,
        'sample_arm': d
    }

# %% [markdown]
# The tables are converted into `pandas` data frames to allow for easier cleaning and manipulation during dataset construction. Any missing values in the biome expression table are filled in with `0.0`.

# %%
import pandas as pd

participant_table = pd.DataFrame.from_dict(rows_participant, orient='index')
expression_table = pd.DataFrame.from_dict(rows_expression, orient='index').fillna(0.0)

# %% [markdown]
# ### Data normalization
#
# The expression data for each measurement point are divided by the total sum to obtain relative expressions.

# %%
expression_table = expression_table.div(expression_table.sum(axis=1), axis=0)

# %% [markdown]
# ### Preview of the participant and expression tables

# %%
participant_table
# Out:
#        age gender  sample_arm
# 19-V1   54      F  before_low
# 04-V4   37      M  after_high
# 20-V3   43      F  before_low
# 22-MP   61      M    midpoint
# 01-V2   46      F   after_low
# ...    ...    ...         ...
# 05-V3   36      M  before_low
# 15-MP   58      F    midpoint
# 20-V4   43      F   after_low
# 07-MP   29      F    midpoint
# 05-V2   36      M  after_high
#
# [100 rows x 3 columns]

# %%
expression_table
# Out:
#        Archaea:Euryarchaeota:Methanobacteria:Methanobacteriales:Methanobacteriaceae:Methanobrevibacter
# 19-V1                                           0.004831                                                \
# 04-V4                                           0.005464
# 20-V3                                           0.008696
# 01-V2                                           0.007246
# 04-V1                                           0.006897
# ...                                                  ...
# 07-V4                                           0.000000
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        Bacteria
# 19-V1  0.067633  \
# 04-V4  0.071038
# 20-V3  0.056522
# 01-V2  0.086957
# 04-V1  0.041379
# ...         ...
# 07-V4  0.080645
# 05-V3  0.104839
# 15-MP  0.081818
# 07-MP  0.058824
# 05-V2  0.095238
#
#        Bacteria:Actinobacteria:Actinobacteria:Bifidobacteriales:Bifidobacteriaceae:Bifidobacterium
# 19-V1                                           0.009662                                            \
# 04-V4                                           0.005464
# 20-V3                                           0.004348
# 01-V2                                           0.007246
# 04-V1                                           0.006897
# ...                                                  ...
# 07-V4                                           0.008065
# 05-V3                                           0.016129
# 15-MP                                           0.018182
# 07-MP                                           0.008403
# 05-V2                                           0.007937
#
#        Bacteria:Actinobacteria:Actinobacteria:Propionibacteriales:Propionibacteriaceae:Granulicoccus
# 19-V1                                           0.004831                                              \
# 04-V4                                           0.000000
# 20-V3                                           0.004348
# 01-V2                                           0.000000
# 04-V1                                           0.000000
# ...                                                  ...
# 07-V4                                           0.000000
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677
# 19-V1                                           0.024155                                                                    \
# 04-V4                                           0.038251
# 20-V3                                           0.017391
# 01-V2                                           0.036232
# 04-V1                                           0.013793
# ...                                                  ...
# 07-V4                                           0.040323
# 05-V3                                           0.000000
# 15-MP                                           0.009091
# 07-MP                                           0.050420
# 05-V2                                           0.023810
#
#        Bacteria:Actinobacteria:Coriobacteriia:Coriobacteriales:Coriobacteriaceae
# 19-V1                                           0.004831                          \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 01-V2                                           0.007246
# 04-V1                                           0.006897
# ...                                                  ...
# 07-V4                                           0.000000
# 05-V3                                           0.000000
# 15-MP                                           0.009091
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        Bacteria:Actinobacteria:Coriobacteriia:Coriobacteriales:Coriobacteriaceae:Collinsella
# 19-V1                                           0.004831                                      \
# 04-V4                                           0.010929
# 20-V3                                           0.000000
# 01-V2                                           0.000000
# 04-V1                                           0.000000
# ...                                                  ...
# 07-V4                                           0.008065
# 05-V3                                           0.008065
# 15-MP                                           0.009091
# 07-MP                                           0.016807
# 05-V2                                           0.007937
#
#        Bacteria:Bacteroidetes  Bacteria:Bacteroidetes:Bacteroidia
# 19-V1                0.019324                            0.009662  \
# 04-V4                0.000000                            0.010929
# 20-V3                0.004348                            0.008696
# 01-V2                0.000000                            0.014493
# 04-V1                0.000000                            0.013793
# ...                       ...                                 ...
# 07-V4                0.056452                            0.016129
# 05-V3                0.048387                            0.024194
# 15-MP                0.000000                            0.036364
# 07-MP                0.016807                            0.016807
# 05-V2                0.031746                            0.023810
#
#        Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales  ...
# 19-V1                                          0.009662  ...  \
# 04-V4                                          0.010929  ...
# 20-V3                                          0.008696  ...
# 01-V2                                          0.000000  ...
# 04-V1                                          0.006897  ...
# ...                                                 ...  ...
# 07-V4                                          0.008065  ...
# 05-V3                                          0.008065  ...
# 15-MP                                          0.018182  ...
# 07-MP                                          0.016807  ...
# 05-V2                                          0.000000  ...
#
#        Eukaryota:Viridiplantae:Streptophyta:Magnoliopsida:Malvales:Malvaceae
# 19-V1                                                0.0                      \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 01-V2                                                0.0
# 04-V1                                                0.0
# ...                                                  ...
# 07-V4                                                0.0
# 05-V3                                                0.0
# 15-MP                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_salyersiae
# 19-V1                                                0.0                                                   \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 01-V2                                                0.0
# 04-V1                                                0.0
# ...                                                  ...
# 07-V4                                                0.0
# 05-V3                                                0.0
# 15-MP                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        Bacteria:Actinobacteria:Coriobacteriia:Eggerthellales:Eggerthellaceae:Adlercreutzia
# 19-V1                                                0.0                                    \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 01-V2                                                0.0
# 04-V1                                                0.0
# ...                                                  ...
# 07-V4                                                0.0
# 05-V3                                                0.0
# 15-MP                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Holdemania:Holdemania_massiliensis
# 19-V1                                                0.0                                                               \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 01-V2                                                0.0
# 04-V1                                                0.0
# ...                                                  ...
# 07-V4                                                0.0
# 05-V3                                                0.0
# 15-MP                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        Bacteria:Firmicutes:Negativicutes:Veillonellales
# 19-V1                                               0.0  \
# 04-V4                                               0.0
# 20-V3                                               0.0
# 01-V2                                               0.0
# 04-V1                                               0.0
# ...                                                 ...
# 07-V4                                               0.0
# 05-V3                                               0.0
# 15-MP                                               0.0
# 07-MP                                               0.0
# 05-V2                                               0.0
#
#        Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Catenibacterium:Catenibacterium_mitsuokai
# 19-V1                                                0.0                                                                      \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 01-V2                                                0.0
# 04-V1                                                0.0
# ...                                                  ...
# 07-V4                                                0.0
# 05-V3                                                0.0
# 15-MP                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        Bacteria:Firmicutes:Clostridia:Clostridiales:Peptostreptococcaceae:Romboutsia:Romboutsia_sp._MT17
# 19-V1                                           0.000000                                                  \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 01-V2                                           0.000000
# 04-V1                                           0.000000
# ...                                                  ...
# 07-V4                                           0.008065
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        Bacteria:Actinobacteria:Actinobacteria:Micrococcales:Micrococcaceae:Arthrobacter
# 19-V1                                           0.000000                                 \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 01-V2                                           0.000000
# 04-V1                                           0.000000
# ...                                                  ...
# 07-V4                                           0.000000
# 05-V3                                           0.008065
# 15-MP                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Fusicatenibacter:Fusicatenibacter_saccharivorans
# 19-V1                                           0.000000                                                              \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 01-V2                                           0.000000
# 04-V1                                           0.000000
# ...                                                  ...
# 07-V4                                           0.000000
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.007937
#
#        Bacteria:Firmicutes:Clostridia:Clostridiales:Syntrophomonadaceae:Syntrophomonas
# 19-V1                                           0.000000
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 01-V2                                           0.000000
# 04-V1                                           0.000000
# ...                                                  ...
# 07-V4                                           0.000000
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.007937
#
# [100 rows x 267 columns]

# %% [markdown]
# ## Dataset preparation
#
# To perform machine learning-based analysis on the DIME study data, we prepared multiple variants of the dataset.
#
# ### Participant+ExpressionEndpoints
# In this variant of the dataset we combined the participant information (age and gender) with the biome expression data of the taxonomy endpoints, i.e., entries that contain exactly 7 taxonomical levels. For the final feature we take the feature **sample_arm**, which describes at which measurement point the Expression measurements were taken as a discrete variable, with values of `before_low`, `after_low`, `midpoint`, `before_high` and `after_high`. Each data example corresponds to a particular participant and measurement point, resulting in a dataset with 100 examples.

# %%
# Prepare the Participant+ExpressionEndpoints dataset

species_endpoints = expression_table.loc[:,[len(tax.split(':')) == 7 for tax in expression_table.columns]].copy() # select only columns that contain exactly 7 taxonomical levels, i.e., they are endpoints

df_ends = participant_table.join(species_endpoints)

# %% [markdown]
# A preview of the Participant+ExpressionEndpoints dataset:

# %%
df_ends
# Out:
#        age gender  sample_arm
# 19-V1   54      F  before_low  \
# 04-V4   37      M  after_high
# 20-V3   43      F  before_low
# 22-MP   61      M    midpoint
# 01-V2   46      F   after_low
# ...    ...    ...         ...
# 05-V3   36      M  before_low
# 15-MP   58      F    midpoint
# 20-V4   43      F   after_low
# 07-MP   29      F    midpoint
# 05-V2   36      M  after_high
#
#        Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677
# 19-V1                                           0.024155                                                                    \
# 04-V4                                           0.038251
# 20-V3                                           0.017391
# 22-MP                                           0.011765
# 01-V2                                           0.036232
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.009091
# 20-V4                                           0.027523
# 07-MP                                           0.050420
# 05-V2                                           0.023810
#
#        Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Porphyromonadaceae:Gabonibacter:Gabonibacter_massiliensis
# 19-V1                                           0.004831                                                           \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.000000
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        Bacteria:Firmicutes:Bacilli:Lactobacillales:Streptococcaceae:Streptococcus:Streptococcus_pyogenes
# 19-V1                                           0.004831                                                  \
# 04-V4                                           0.000000
# 20-V3                                           0.004348
# 22-MP                                           0.000000
# 01-V2                                           0.014493
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.009091
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Merdibacter:Merdibacter_massiliensis
# 19-V1                                           0.004831                                                                 \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.000000
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        Bacteria:Proteobacteria:Deltaproteobacteria:Desulfovibrionales:Desulfovibrionaceae:Mailhella:Mailhella_massiliensis
# 19-V1                                           0.004831                                                                    \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.000000
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        Bacteria:Verrucomicrobia:Verrucomicrobiae:Verrucomicrobiales:Akkermansiaceae:Akkermansia:Akkermansia_muciniphila
# 19-V1                                           0.004831                                                                 \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.007246
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_coprocola
# 19-V1                                           0.000000                                                  \
# 04-V4                                           0.005464
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.000000
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        ...
# 19-V1  ...  \
# 04-V4  ...
# 20-V3  ...
# 22-MP  ...
# 01-V2  ...
# ...    ...
# 05-V3  ...
# 15-MP  ...
# 20-V4  ...
# 07-MP  ...
# 05-V2  ...
#
#        Bacteria:Firmicutes:Bacilli:Lactobacillales:Streptococcaceae:Lactococcus:Lactococcus_lactis
# 19-V1                                                0.0                                            \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 22-MP                                                0.0
# 01-V2                                                0.0
# ...                                                  ...
# 05-V3                                                0.0
# 15-MP                                                0.0
# 20-V4                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Erysipelatoclostridium:Erysipelatoclostridium_sp._SNUG30386
# 19-V1                                                0.0                                                                                        \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 22-MP                                                0.0
# 01-V2                                                0.0
# ...                                                  ...
# 05-V3                                                0.0
# 15-MP                                                0.0
# 20-V4                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        Bacteria:Fusobacteria:Fusobacteriia:Fusobacteriales:Leptotrichiaceae:Sneathia:Sneathia_amnii
# 19-V1                                                0.0                                             \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 22-MP                                                0.0
# 01-V2                                                0.0
# ...                                                  ...
# 05-V3                                                0.0
# 15-MP                                                0.0
# 20-V4                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Roseburia:Roseburia_sp._499
# 19-V1                                                0.0                                         \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 22-MP                                                0.0
# 01-V2                                                0.0
# ...                                                  ...
# 05-V3                                                0.0
# 15-MP                                                0.0
# 20-V4                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        Bacteria:Firmicutes:Clostridia:Clostridiales:Ruminococcaceae:Negativibacillus:Negativibacillus_massiliensis
# 19-V1                                                0.0                                                            \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 22-MP                                                0.0
# 01-V2                                                0.0
# ...                                                  ...
# 05-V3                                                0.0
# 15-MP                                                0.0
# 20-V4                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_salyersiae
# 19-V1                                                0.0                                                   \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 22-MP                                                0.0
# 01-V2                                                0.0
# ...                                                  ...
# 05-V3                                                0.0
# 15-MP                                                0.0
# 20-V4                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Holdemania:Holdemania_massiliensis
# 19-V1                                                0.0                                                               \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 22-MP                                                0.0
# 01-V2                                                0.0
# ...                                                  ...
# 05-V3                                                0.0
# 15-MP                                                0.0
# 20-V4                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Catenibacterium:Catenibacterium_mitsuokai
# 19-V1                                                0.0                                                                      \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 22-MP                                                0.0
# 01-V2                                                0.0
# ...                                                  ...
# 05-V3                                                0.0
# 15-MP                                                0.0
# 20-V4                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        Bacteria:Firmicutes:Clostridia:Clostridiales:Peptostreptococcaceae:Romboutsia:Romboutsia_sp._MT17
# 19-V1                                                0.0                                                  \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 22-MP                                                0.0
# 01-V2                                                0.0
# ...                                                  ...
# 05-V3                                                0.0
# 15-MP                                                0.0
# 20-V4                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Fusicatenibacter:Fusicatenibacter_saccharivorans
# 19-V1                                           0.000000
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.000000
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.007937
#
# [100 rows x 55 columns]

# %% [markdown]
# ### Participant+ExpressionEndpoints+ExpressionAggregates
#
# This variant of the dataset expands on the one described above, by adding aggregates over all taxonomic levels, such as total values for `Archaea`, `Archaea:Methanobacteriota`, etc. As before this dataset consists of 100 examples.

# %%
# Prepare the Participant+ExpressionEndpoints+ExpressionAggregates dataset

import warnings
warnings.filterwarnings("ignore")

df_agg = df_ends.copy()

df_agg["TOTAL"] = 0


for name in expression_table:
    taxonomy = name.replace('?', '').strip(':').split(':')
    if taxonomy != ['']:
        path = ''
        for tax in taxonomy:
            path += ";" + tax
            path = path.strip(':')
            if path not in df_agg:
                df_agg[path] = 0
            if path != name: # do not override existing endpoints
                df_agg[path] += expression_table[name]
    df_agg['TOTAL'] += expression_table[name]

df_agg = df_agg.copy()

# %% [markdown]
# A preview of the Participant+ExpressionEndpoints+ExpressionAggregates dataset:

# %%
df_agg
# Out:
#        age gender  sample_arm
# 19-V1   54      F  before_low  \
# 04-V4   37      M  after_high
# 20-V3   43      F  before_low
# 22-MP   61      M    midpoint
# 01-V2   46      F   after_low
# ...    ...    ...         ...
# 05-V3   36      M  before_low
# 15-MP   58      F    midpoint
# 20-V4   43      F   after_low
# 07-MP   29      F    midpoint
# 05-V2   36      M  after_high
#
#        Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677
# 19-V1                                           0.024155                                                                    \
# 04-V4                                           0.038251
# 20-V3                                           0.017391
# 22-MP                                           0.011765
# 01-V2                                           0.036232
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.009091
# 20-V4                                           0.027523
# 07-MP                                           0.050420
# 05-V2                                           0.023810
#
#        Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Porphyromonadaceae:Gabonibacter:Gabonibacter_massiliensis
# 19-V1                                           0.004831                                                           \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.000000
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        Bacteria:Firmicutes:Bacilli:Lactobacillales:Streptococcaceae:Streptococcus:Streptococcus_pyogenes
# 19-V1                                           0.004831                                                  \
# 04-V4                                           0.000000
# 20-V3                                           0.004348
# 22-MP                                           0.000000
# 01-V2                                           0.014493
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.009091
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Merdibacter:Merdibacter_massiliensis
# 19-V1                                           0.004831                                                                 \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.000000
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        Bacteria:Proteobacteria:Deltaproteobacteria:Desulfovibrionales:Desulfovibrionaceae:Mailhella:Mailhella_massiliensis
# 19-V1                                           0.004831                                                                    \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.000000
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        Bacteria:Verrucomicrobia:Verrucomicrobiae:Verrucomicrobiales:Akkermansiaceae:Akkermansia:Akkermansia_muciniphila
# 19-V1                                           0.004831                                                                 \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.007246
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_coprocola
# 19-V1                                           0.000000                                                  \
# 04-V4                                           0.005464
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.000000
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        ...
# 19-V1  ...  \
# 04-V4  ...
# 20-V3  ...
# 22-MP  ...
# 01-V2  ...
# ...    ...
# 05-V3  ...
# 15-MP  ...
# 20-V4  ...
# 07-MP  ...
# 05-V2  ...
#
#        ;Bacteria;Bacteroidetes;Bacteroidia;Bacteroidales;Bacteroidaceae;Bacteroides;Bacteroides_salyersiae
# 19-V1                                                0.0                                                    \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 22-MP                                                0.0
# 01-V2                                                0.0
# ...                                                  ...
# 05-V3                                                0.0
# 15-MP                                                0.0
# 20-V4                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        ;Bacteria;Actinobacteria;Coriobacteriia;Eggerthellales;Eggerthellaceae;Adlercreutzia
# 19-V1                                                0.0                                     \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 22-MP                                                0.0
# 01-V2                                                0.0
# ...                                                  ...
# 05-V3                                                0.0
# 15-MP                                                0.0
# 20-V4                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        ;Bacteria;Firmicutes;Erysipelotrichia;Erysipelotrichales;Erysipelotrichaceae;Holdemania;Holdemania_massiliensis
# 19-V1                                                0.0                                                                \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 22-MP                                                0.0
# 01-V2                                                0.0
# ...                                                  ...
# 05-V3                                                0.0
# 15-MP                                                0.0
# 20-V4                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        ;Bacteria;Firmicutes;Erysipelotrichia;Erysipelotrichales;Erysipelotrichaceae;Catenibacterium;Catenibacterium_mitsuokai
# 19-V1                                                0.0                                                                       \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 22-MP                                                0.0
# 01-V2                                                0.0
# ...                                                  ...
# 05-V3                                                0.0
# 15-MP                                                0.0
# 20-V4                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        ;Bacteria;Firmicutes;Clostridia;Clostridiales;Peptostreptococcaceae;Romboutsia;Romboutsia_sp._MT17
# 19-V1                                                0.0                                                   \
# 04-V4                                                0.0
# 20-V3                                                0.0
# 22-MP                                                0.0
# 01-V2                                                0.0
# ...                                                  ...
# 05-V3                                                0.0
# 15-MP                                                0.0
# 20-V4                                                0.0
# 07-MP                                                0.0
# 05-V2                                                0.0
#
#        ;Bacteria;Actinobacteria;Actinobacteria;Micrococcales;Micrococcaceae
# 19-V1                                           0.000000                     \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.000000
# ...                                                  ...
# 05-V3                                           0.008065
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        ;Bacteria;Actinobacteria;Actinobacteria;Micrococcales;Micrococcaceae;Arthrobacter
# 19-V1                                           0.000000                                  \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.000000
# ...                                                  ...
# 05-V3                                           0.008065
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.000000
#
#        ;Bacteria;Firmicutes;Clostridia;Clostridiales;Lachnospiraceae;Fusicatenibacter;Fusicatenibacter_saccharivorans
# 19-V1                                           0.000000                                                               \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.000000
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.007937
#
#        ;Bacteria;Firmicutes;Clostridia;Clostridiales;Syntrophomonadaceae
# 19-V1                                           0.000000                  \
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.000000
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.007937
#
#        ;Bacteria;Firmicutes;Clostridia;Clostridiales;Syntrophomonadaceae;Syntrophomonas
# 19-V1                                           0.000000
# 04-V4                                           0.000000
# 20-V3                                           0.000000
# 22-MP                                           0.000000
# 01-V2                                           0.000000
# ...                                                  ...
# 05-V3                                           0.000000
# 15-MP                                           0.000000
# 20-V4                                           0.000000
# 07-MP                                           0.000000
# 05-V2                                           0.007937
#
# [100 rows x 411 columns]

# %% [markdown]
# ### Participant+ExpressionDifference
#
# In this variant, we combined participant information (age and gender) with the difference in the Expression measurements after a food treatment was done, i.e., the difference between measurement points **after_low** and **before_low** as well as the difference between after_high and before_high. The final feature encodes which dietary treatment was done, i.e., **high** and **low**. As all midpoint data is dropped, and the remaining before and after data points are paired up, the dataset consists of 40 examples.

# %%
# Prepare the Participant+ExpressionDifference dataset

df = df_ends.copy()

df["participant"] = df.index.astype(str)

df["participant"] = df["participant"].apply(lambda p: p.split('-')[0])

patient_features = ['age', 'gender']

def diff(d):
    return d[1] - d[0]

maps = {k: diff for k in df_ends.columns if k != "sample_arm"}
maps.update(
    {f: "first" for f in patient_features}
)

df_diff_low = df[(df["sample_arm"] == "before_low") | (df["sample_arm"] == "after_low")].groupby(by="participant").agg(
    maps
)

df_diff_high = df[(df["sample_arm"] == "before_high") | (df["sample_arm"] == "after_high")].groupby(by="participant").agg(
    maps
)


df_diff_low["diet"] = "low"
df_diff_low["p"] = df_diff_low.index.astype(str) + "-low"
df_diff_low.set_index("p", inplace=True)

df_diff_high["diet"] = "high"
df_diff_high["p"] = df_diff_high.index.astype(str) + "-high"
df_diff_high.set_index("p", inplace=True)

df_diff = pd.concat([df_diff_low, df_diff_high])

# %% [markdown]
# A preview of the Participant+ExpressionEndpoints+ExpressionAggregates dataset:

# %%
df_diff
# Out:
#          age gender
# p
# 01-low    46      F  \
# 02-low    44      M
# 04-low    37      M
# 05-low    36      M
# 06-low    29      F
# 07-low    29      F
# 09-low    32      F
# 13-low    37      M
# 14-low    43      F
# 15-low    58      F
# 16-low    28      M
# 18-low    48      F
# 19-low    54      F
# 20-low    43      F
# 21-low    61      F
# 22-low    61      M
# 23-low    59      F
# 24-low    26      M
# 25-low    25      F
# 27-low    28      M
# 01-high   46      F
# 02-high   44      M
# 04-high   37      M
# 05-high   36      M
# 06-high   29      F
# 07-high   29      F
# 09-high   32      F
# 13-high   37      M
# 14-high   43      F
# 15-high   58      F
# 16-high   28      M
# 18-high   48      F
# 19-high   54      F
# 20-high   43      F
# 21-high   61      F
# 22-high   61      M
# 23-high   59      F
# 24-high   26      M
# 25-high   25      F
# 27-high   28      M
#
#          Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677
# p
# 01-low                                           -0.020359                                                                    \
# 02-low                                            0.011029
# 04-low                                            0.015619
# 05-low                                           -0.043478
# 06-low                                            0.043431
# 07-low                                           -0.013731
# 09-low                                            0.037166
# 13-low                                            0.018556
# 14-low                                            0.029579
# 15-low                                           -0.000637
# 16-low                                           -0.012083
# 18-low                                           -0.034463
# 19-low                                            0.010131
# 20-low                                            0.010132
# 21-low                                           -0.027863
# 22-low                                            0.003779
# 23-low                                           -0.012916
# 24-low                                            0.046218
# 25-low                                           -0.010867
# 27-low                                           -0.018219
# 01-high                                          -0.044505
# 02-high                                           0.000483
# 04-high                                          -0.009842
# 05-high                                          -0.029762
# 06-high                                          -0.052123
# 07-high                                          -0.006357
# 09-high                                           0.012452
# 13-high                                           0.052174
# 14-high                                          -0.008475
# 15-high                                          -0.044275
# 16-high                                          -0.002632
# 18-high                                          -0.024731
# 19-high                                           0.006105
# 20-high                                           0.032856
# 21-high                                           0.001531
# 22-high                                           0.002631
# 23-high                                          -0.025494
# 24-high                                          -0.010078
# 25-high                                          -0.010870
# 27-high                                          -0.019145
#
#          Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Porphyromonadaceae:Gabonibacter:Gabonibacter_massiliensis
# p
# 01-low                                            0.000000                                                           \
# 02-low                                            0.000000
# 04-low                                            0.000000
# 05-low                                            0.000000
# 06-low                                            0.000000
# 07-low                                            0.000000
# 09-low                                            0.000000
# 13-low                                            0.000000
# 14-low                                            0.000000
# 15-low                                            0.000000
# 16-low                                            0.000000
# 18-low                                            0.000000
# 19-low                                           -0.004831
# 20-low                                            0.000000
# 21-low                                            0.000000
# 22-low                                            0.000000
# 23-low                                            0.000000
# 24-low                                            0.000000
# 25-low                                            0.000000
# 27-low                                            0.000000
# 01-high                                           0.000000
# 02-high                                           0.000000
# 04-high                                           0.000000
# 05-high                                           0.000000
# 06-high                                           0.000000
# 07-high                                           0.000000
# 09-high                                           0.000000
# 13-high                                           0.000000
# 14-high                                           0.000000
# 15-high                                           0.000000
# 16-high                                           0.000000
# 18-high                                           0.000000
# 19-high                                           0.000000
# 20-high                                           0.000000
# 21-high                                           0.000000
# 22-high                                           0.000000
# 23-high                                           0.000000
# 24-high                                           0.000000
# 25-high                                           0.000000
# 27-high                                           0.000000
#
#          Bacteria:Firmicutes:Bacilli:Lactobacillales:Streptococcaceae:Streptococcus:Streptococcus_pyogenes
# p
# 01-low                                            0.009317                                                  \
# 02-low                                            0.000000
# 04-low                                           -0.007911
# 05-low                                            0.000000
# 06-low                                            0.011236
# 07-low                                            0.016129
# 09-low                                            0.000000
# 13-low                                            0.000000
# 14-low                                            0.000000
# 15-low                                           -0.006579
# 16-low                                            0.009174
# 18-low                                            0.009346
# 19-low                                            0.000883
# 20-low                                           -0.004348
# 21-low                                            0.000000
# 22-low                                            0.000000
# 23-low                                           -0.001232
# 24-low                                           -0.008403
# 25-low                                            0.000000
# 27-low                                            0.000000
# 01-high                                           0.000000
# 02-high                                           0.000000
# 04-high                                           0.005682
# 05-high                                           0.000000
# 06-high                                           0.000000
# 07-high                                           0.000000
# 09-high                                          -0.008197
# 13-high                                           0.008696
# 14-high                                           0.000000
# 15-high                                           0.000000
# 16-high                                          -0.008772
# 18-high                                           0.010753
# 19-high                                          -0.004950
# 20-high                                          -0.004405
# 21-high                                          -0.006993
# 22-high                                           0.000000
# 23-high                                           0.000000
# 24-high                                           0.000000
# 25-high                                           0.000000
# 27-high                                           0.000000
#
#          Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Merdibacter:Merdibacter_massiliensis
# p
# 01-low                                            0.000000                                                                 \
# 02-low                                            0.000000
# 04-low                                            0.000000
# 05-low                                            0.000000
# 06-low                                            0.000000
# 07-low                                            0.000000
# 09-low                                            0.000000
# 13-low                                            0.000000
# 14-low                                            0.000000
# 15-low                                            0.000000
# 16-low                                            0.000000
# 18-low                                            0.000000
# 19-low                                           -0.004831
# 20-low                                            0.000000
# 21-low                                            0.000000
# 22-low                                            0.000000
# 23-low                                            0.000000
# 24-low                                            0.000000
# 25-low                                            0.000000
# 27-low                                            0.000000
# 01-high                                           0.000000
# 02-high                                           0.000000
# 04-high                                           0.000000
# 05-high                                           0.000000
# 06-high                                           0.000000
# 07-high                                           0.000000
# 09-high                                           0.000000
# 13-high                                           0.000000
# 14-high                                           0.000000
# 15-high                                           0.000000
# 16-high                                           0.000000
# 18-high                                           0.000000
# 19-high                                           0.000000
# 20-high                                           0.000000
# 21-high                                           0.000000
# 22-high                                           0.000000
# 23-high                                           0.000000
# 24-high                                           0.000000
# 25-high                                           0.000000
# 27-high                                           0.000000
#
#          Bacteria:Proteobacteria:Deltaproteobacteria:Desulfovibrionales:Desulfovibrionaceae:Mailhella:Mailhella_massiliensis
# p
# 01-low                                            0.000000                                                                    \
# 02-low                                            0.000000
# 04-low                                            0.000000
# 05-low                                            0.000000
# 06-low                                            0.000000
# 07-low                                            0.000000
# 09-low                                            0.000000
# 13-low                                            0.000000
# 14-low                                            0.000000
# 15-low                                            0.000000
# 16-low                                            0.000000
# 18-low                                            0.000000
# 19-low                                            0.000883
# 20-low                                            0.000000
# 21-low                                            0.000000
# 22-low                                            0.000000
# 23-low                                            0.000000
# 24-low                                            0.000000
# 25-low                                            0.000000
# 27-low                                            0.000000
# 01-high                                           0.000000
# 02-high                                           0.000000
# 04-high                                           0.000000
# 05-high                                           0.000000
# 06-high                                           0.000000
# 07-high                                           0.000000
# 09-high                                           0.000000
# 13-high                                           0.000000
# 14-high                                           0.000000
# 15-high                                           0.000000
# 16-high                                           0.000000
# 18-high                                           0.000000
# 19-high                                          -0.004720
# 20-high                                           0.000000
# 21-high                                           0.000000
# 22-high                                           0.000000
# 23-high                                           0.000000
# 24-high                                           0.000000
# 25-high                                           0.000000
# 27-high                                           0.000000
#
#          Bacteria:Verrucomicrobia:Verrucomicrobiae:Verrucomicrobiales:Akkermansiaceae:Akkermansia:Akkermansia_muciniphila
# p
# 01-low                                           -0.007246                                                                 \
# 02-low                                            0.000000
# 04-low                                            0.000000
# 05-low                                            0.000000
# 06-low                                            0.000000
# 07-low                                            0.000000
# 09-low                                            0.000000
# 13-low                                            0.000000
# 14-low                                            0.000000
# 15-low                                            0.000000
# 16-low                                           -0.008130
# 18-low                                            0.000000
# 19-low                                           -0.004831
# 20-low                                            0.000000
# 21-low                                            0.000000
# 22-low                                            0.000000
# 23-low                                            0.000000
# 24-low                                            0.000000
# 25-low                                            0.000000
# 27-low                                            0.000000
# 01-high                                          -0.007299
# 02-high                                           0.000000
# 04-high                                           0.000000
# 05-high                                           0.000000
# 06-high                                           0.000000
# 07-high                                           0.000000
# 09-high                                           0.000000
# 13-high                                           0.000000
# 14-high                                           0.000000
# 15-high                                           0.000000
# 16-high                                           0.000000
# 18-high                                           0.000000
# 19-high                                           0.000000
# 20-high                                           0.000000
# 21-high                                           0.000000
# 22-high                                           0.000000
# 23-high                                           0.000000
# 24-high                                           0.000000
# 25-high                                           0.000000
# 27-high                                           0.000000
#
#          Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_coprocola
# p
# 01-low                                            0.000000                                                  \
# 02-low                                            0.000000
# 04-low                                            0.000000
# 05-low                                            0.000000
# 06-low                                            0.000000
# 07-low                                            0.000000
# 09-low                                            0.000000
# 13-low                                            0.011236
# 14-low                                            0.000000
# 15-low                                            0.000000
# 16-low                                            0.000000
# 18-low                                            0.000000
# 19-low                                            0.000000
# 20-low                                            0.000000
# 21-low                                            0.000000
# 22-low                                            0.000000
# 23-low                                            0.000000
# 24-low                                            0.000000
# 25-low                                            0.000000
# 27-low                                            0.008547
# 01-high                                           0.000000
# 02-high                                           0.000000
# 04-high                                          -0.005464
# 05-high                                           0.000000
# 06-high                                           0.000000
# 07-high                                           0.000000
# 09-high                                           0.000000
# 13-high                                           0.000000
# 14-high                                           0.000000
# 15-high                                           0.000000
# 16-high                                           0.000000
# 18-high                                           0.000000
# 19-high                                           0.000000
# 20-high                                           0.000000
# 21-high                                           0.000000
# 22-high                                           0.000000
# 23-high                                           0.000000
# 24-high                                           0.000000
# 25-high                                           0.000000
# 27-high                                           0.000000
#
#          Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Prevotellaceae:Massiliprevotella:Massiliprevotella_massiliensis
# p
# 01-low                                            0.000000                                                                 \
# 02-low                                            0.000000
# 04-low                                           -0.006897
# 05-low                                            0.000000
# 06-low                                            0.000000
# 07-low                                            0.000000
# 09-low                                            0.000000
# 13-low                                            0.000000
# 14-low                                            0.000000
# 15-low                                            0.000000
# 16-low                                            0.000000
# 18-low                                            0.000000
# 19-low                                            0.000000
# 20-low                                            0.000000
# 21-low                                            0.009174
# 22-low                                            0.000000
# 23-low                                            0.000000
# 24-low                                            0.000000
# 25-low                                            0.000000
# 27-low                                            0.000000
# 01-high                                           0.000000
# 02-high                                           0.000000
# 04-high                                          -0.005247
# 05-high                                           0.000000
# 06-high                                           0.000000
# 07-high                                           0.000000
# 09-high                                           0.000000
# 13-high                                           0.000000
# 14-high                                           0.000000
# 15-high                                           0.000000
# 16-high                                           0.000000
# 18-high                                           0.000000
# 19-high                                           0.000000
# 20-high                                           0.000000
# 21-high                                           0.000000
# 22-high                                           0.000000
# 23-high                                           0.000000
# 24-high                                           0.000000
# 25-high                                           0.000000
# 27-high                                           0.000000
#
#          ...
# p        ...
# 01-low   ...  \
# 02-low   ...
# 04-low   ...
# 05-low   ...
# 06-low   ...
# 07-low   ...
# 09-low   ...
# 13-low   ...
# 14-low   ...
# 15-low   ...
# 16-low   ...
# 18-low   ...
# 19-low   ...
# 20-low   ...
# 21-low   ...
# 22-low   ...
# 23-low   ...
# 24-low   ...
# 25-low   ...
# 27-low   ...
# 01-high  ...
# 02-high  ...
# 04-high  ...
# 05-high  ...
# 06-high  ...
# 07-high  ...
# 09-high  ...
# 13-high  ...
# 14-high  ...
# 15-high  ...
# 16-high  ...
# 18-high  ...
# 19-high  ...
# 20-high  ...
# 21-high  ...
# 22-high  ...
# 23-high  ...
# 24-high  ...
# 25-high  ...
# 27-high  ...
#
#          Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Erysipelatoclostridium:Erysipelatoclostridium_sp._SNUG30386
# p
# 01-low                                            0.000000                                                                                        \
# 02-low                                            0.000000
# 04-low                                            0.000000
# 05-low                                            0.000000
# 06-low                                            0.000000
# 07-low                                            0.000000
# 09-low                                            0.000000
# 13-low                                            0.000000
# 14-low                                            0.000000
# 15-low                                            0.000000
# 16-low                                            0.000000
# 18-low                                            0.000000
# 19-low                                            0.000000
# 20-low                                            0.000000
# 21-low                                            0.000000
# 22-low                                            0.000000
# 23-low                                            0.000000
# 24-low                                            0.000000
# 25-low                                            0.000000
# 27-low                                            0.000000
# 01-high                                           0.000000
# 02-high                                           0.000000
# 04-high                                           0.000000
# 05-high                                           0.000000
# 06-high                                           0.000000
# 07-high                                           0.000000
# 09-high                                           0.000000
# 13-high                                           0.000000
# 14-high                                           0.000000
# 15-high                                           0.000000
# 16-high                                           0.000000
# 18-high                                           0.010753
# 19-high                                           0.000000
# 20-high                                           0.000000
# 21-high                                           0.000000
# ...
#
#          Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Catenibacterium:Catenibacterium_mitsuokai
# p
# 01-low                                            0.000000                                                                      \
# 02-low                                            0.000000
# 04-low                                            0.000000
# 05-low                                            0.000000
# 06-low                                            0.000000
# 07-low                                            0.000000
# 09-low                                            0.000000
# 13-low                                            0.000000
# 14-low                                            0.000000
# 15-low                                            0.000000
# 16-low                                            0.000000
# 18-low                                            0.000000
# 19-low                                            0.000000
# 20-low                                            0.000000
# 21-low                                            0.009174
# 22-low                                            0.000000
# 23-low                                            0.000000
# 24-low                                            0.000000
# 25-low                                            0.000000
# 27-low                                            0.000000
# 01-high                                           0.000000
# 02-high                                           0.000000
# 04-high                                           0.000000
# 05-high                                           0.000000
# 06-high                                           0.000000
# 07-high                                           0.000000
# 09-high                                           0.000000
# 13-high                                           0.000000
# 14-high                                           0.000000
# 15-high                                           0.000000
# 16-high                                           0.000000
# 18-high                                           0.000000
# 19-high                                           0.000000
# 20-high                                           0.000000
# 21-high                                           0.000000
# 22-high                                           0.000000
# 23-high                                           0.000000
# 24-high                                           0.000000
# 25-high                                           0.000000
# 27-high                                           0.000000
#
#          Bacteria:Firmicutes:Clostridia:Clostridiales:Peptostreptococcaceae:Romboutsia:Romboutsia_sp._MT17
# p
# 01-low                                            0.000000                                                  \
# 02-low                                            0.000000
# 04-low                                            0.000000
# 05-low                                            0.000000
# 06-low                                            0.000000
# 07-low                                            0.008065
# 09-low                                            0.000000
# 13-low                                            0.000000
# 14-low                                            0.000000
# 15-low                                            0.000000
# 16-low                                            0.000000
# 18-low                                            0.000000
# 19-low                                            0.000000
# 20-low                                            0.000000
# 21-low                                            0.000000
# 22-low                                            0.000000
# 23-low                                            0.000000
# 24-low                                            0.000000
# 25-low                                            0.000000
# 27-low                                            0.000000
# 01-high                                           0.000000
# 02-high                                           0.000000
# 04-high                                           0.000000
# 05-high                                           0.000000
# 06-high                                           0.000000
# 07-high                                           0.000000
# 09-high                                           0.000000
# 13-high                                           0.000000
# 14-high                                           0.000000
# 15-high                                           0.000000
# 16-high                                           0.000000
# 18-high                                           0.000000
# 19-high                                           0.000000
# 20-high                                           0.000000
# 21-high                                           0.000000
# 22-high                                           0.000000
# 23-high                                           0.000000
# 24-high                                           0.000000
# 25-high                                           0.000000
# 27-high                                           0.000000
#
#          Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Fusicatenibacter:Fusicatenibacter_saccharivorans
# p
# 01-low                                            0.000000                                                              \
# 02-low                                            0.000000
# 04-low                                            0.000000
# 05-low                                            0.000000
# 06-low                                            0.000000
# 07-low                                            0.000000
# 09-low                                            0.000000
# 13-low                                            0.000000
# 14-low                                            0.000000
# 15-low                                            0.000000
# 16-low                                            0.000000
# 18-low                                            0.000000
# 19-low                                            0.000000
# 20-low                                            0.000000
# 21-low                                            0.000000
# 22-low                                            0.000000
# 23-low                                            0.000000
# 24-low                                            0.000000
# 25-low                                            0.000000
# 27-low                                            0.000000
# 01-high                                           0.000000
# 02-high                                           0.000000
# 04-high                                           0.000000
# 05-high                                           0.007937
# 06-high                                           0.000000
# 07-high                                           0.000000
# 09-high                                           0.000000
# 13-high                                           0.000000
# 14-high                                           0.000000
# 15-high                                           0.000000
# 16-high                                           0.000000
# 18-high                                           0.000000
# 19-high                                           0.000000
# 20-high                                           0.000000
# 21-high                                           0.000000
# 22-high                                           0.000000
# 23-high                                           0.000000
# 24-high                                           0.000000
# 25-high                                           0.000000
# 27-high                                           0.000000
#
#          diet
# p
# 01-low    low
# 02-low    low
# 04-low    low
# 05-low    low
# 06-low    low
# 07-low    low
# 09-low    low
# 13-low    low
# 14-low    low
# 15-low    low
# 16-low    low
# 18-low    low
# 19-low    low
# 20-low    low
# 21-low    low
# 22-low    low
# 23-low    low
# 24-low    low
# 25-low    low
# 27-low    low
# 01-high  high
# 02-high  high
# 04-high  high
# 05-high  high
# 06-high  high
# 07-high  high
# 09-high  high
# 13-high  high
# 14-high  high
# 15-high  high
# 16-high  high
# 18-high  high
# 19-high  high
# 20-high  high
# 21-high  high
# 22-high  high
# 23-high  high
# 24-high  high
# 25-high  high
# 27-high  high
#
# [40 rows x 55 columns]

# %% [markdown]
# ## Machine learning analysis
#
# We use the [Orange](https://orangedatamining.com/) data mining framework to perform the analysis. Before applying machine learning methods to the prepared datasets, we need to transform them into a compatible format.

# %%
# Convert datasets into Orange tables

from Orange.data.pandas_compat import table_from_frame
from Orange.data.domain import Domain
from Orange.data.table import Table

def convert_to_orange_table(data_frame, target_variable):
    table = table_from_frame(data_frame, force_nominal=False)
    target_idx = None
    for i, a in enumerate(table.domain.attributes):
        if a.name == target_variable:
            target_idx = i
            break
    descriptives = [a for i, a in enumerate(table.domain.attributes) if i != target_idx]
    domain = Domain(descriptives, table.domain.attributes[target_idx])
    return Table.from_table(domain, table)

table_ends = convert_to_orange_table(df_ends, 'sample_arm')
table_agg = convert_to_orange_table(df_agg, 'sample_arm')
table_diff = convert_to_orange_table(df_diff, 'diet')

# %% [markdown]
# The prepared datasets are collected into a list along with their descriptors.

# %%
DATASETS = [("Participant+ExpressionEndpoints", table_ends), ("Participant+ExpressionEndpoints+ExpressionAggregates", table_agg), ("Participant+ExpressionDifference", table_diff)]

# %% [markdown]
# ### Decision tree
#
# We learn decision trees on all three of the datasets and print them out. The obtained models are presented in only in textual form. By examining the structure and hierarchy of the tree, one can determine which features are more influential in making predictions. In particular, the features closer to the root affect more data and are thus prescribed a higher influence, while features appearing deeper into the tree affect smaller portions of data and are thus deemed less influential.

# %%
from Orange.classification import TreeLearner

import Orange

def print_tree(node, level=0):
    """String representation of tree for debug purposees"""
    res = ""
    for child in node.children:
        if child:
            res += (f"{'    ' * level}{node.attr.name} {child.description}: {child.value if type(child) == Orange.tree.Node else ''}\n")
            res += print_tree(child, level + 1)
    return res

for table_name, table in DATASETS:
    model = TreeLearner(min_samples_leaf=5).fit_storage(table)

    print(f"Decision tree for {table_name}")

    print(print_tree(model.root))
    
    print("------------------------------------------------------------------------------------")
# Out:
# Decision tree for Participant+ExpressionEndpoints
# Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Roseburia:Roseburia_hominis ≤ 0:
#     Bacteria:Firmicutes:Bacilli:Lactobacillales:Streptococcaceae:Streptococcus:Streptococcus_pyogenes ≤ 0.00917431:
#         Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ 0.00909091: [0. 0. 2. 1. 4.]
#         Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > 0.00909091:
#             Bacteria:Firmicutes:Bacilli:Lactobacillales:Streptococcaceae:Streptococcus:Streptococcus_pyogenes ≤ 0.00588235:
#                 Bacteria:Firmicutes:Clostridia:Clostridiales:Ruminococcaceae:Ruminococcus:Ruminococcus_bromii ≤ 0:
#                     Bacteria:Firmicutes:Bacilli:Lactobacillales:Streptococcaceae:Streptococcus:Streptococcus_pyogenes ≤ 0.00483092:
#                         Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Sutterellaceae:Parasutterella:Parasutterella_secunda ≤ 0.00434783:
#                             Bacteria:Actinobacteria:Coriobacteriia:Coriobacteriales:Coriobacteriaceae:Collinsella:Collinsella_aerofaciens ≤ 0.00847458:
#                                 Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ 0.025641:
#                                     gender F: [2. 2. 0. 3. 0.]
#                                     gender M: [2. 2. 0. 1. 2.]
#                                 Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > 0.025641:
#                                     Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ 0.0347222: [0. 2. 1. 1. 2.]
#                                     Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > 0.0347222:
#                                         Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ 0.0438596: [4. 3. 2. 0. 0.]
#                                         Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > 0.0438596:
#                                             Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ 0.0535714: [0. 1. 3. 0. 2.]
#                                             Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > 0.0535714:
#                                                 age ≤ 36: [2. 1. 0. 2. 1.]
#                                                 age > 36: [1. 1. 3. 1. 0.]
#                             Bacteria:Actinobacteria:Coriobacteriia:Coriobacteriales:Coriobacteriaceae:Collinsella:Collinsella_aerofaciens > 0.00847458: [1. 0. 2. 1. 3.]
#                         Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Sutterellaceae:Parasutterella:Parasutterella_secunda > 0.00434783: [3. 0. 2. 0. 1.]
#                     Bacteria:Firmicutes:Bacilli:Lactobacillales:Streptococcaceae:Streptococcus:Streptococcus_pyogenes > 0.00483092: [0. 3. 2. 0. 1.]
#                 Bacteria:Firmicutes:Clostridia:Clostridiales:Ruminococcaceae:Ruminococcus:Ruminococcus_bromii > 0: [0. 1. 0. 2. 2.]
#             Bacteria:Firmicutes:Bacilli:Lactobacillales:Streptococcaceae:Streptococcus:Streptococcus_pyogenes > 0.00588235:
#                 Bacteria:Firmicutes:Bacilli:Lactobacillales:Streptococcaceae:Streptococcus:Streptococcus_pyogenes ≤ 0.00840336: [0. 0. 2. 3. 0.]
#                 Bacteria:Firmicutes:Bacilli:Lactobacillales:Streptococcaceae:Streptococcus:Streptococcus_pyogenes > 0.00840336: [1. 0. 1. 1. 2.]
#     Bacteria:Firmicutes:Bacilli:Lactobacillales:Streptococcaceae:Streptococcus:Streptococcus_pyogenes > 0.00917431: [1. 4. 0. 1. 0.]
# Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Roseburia:Roseburia_hominis > 0: [3. 0. 0. 3. 0.]
#
# ------------------------------------------------------------------------------------
# Decision tree for Participant+ExpressionEndpoints+ExpressionAggregates
# Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Roseburia:Roseburia_hominis ≤ 0:
#     TOTAL ≤ 1:
#         Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ 0.015873: [0. 0. 2. 3. 3.]
#         Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > 0.015873:
#             Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ 0.0328947:
#                 Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ 0.0220588: [2. 1. 0. 1. 1.]
#                 Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > 0.0220588: [1. 4. 0. 1. 0.]
#             Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > 0.0328947:
#                 Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ 0.0413223: [2. 2. 3. 0. 2.]
#                 Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > 0.0413223:
#                     Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ 0.0604027: [5. 0. 0. 0. 4.]
#                     Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > 0.0604027: [3. 1. 1. 0. 0.]
#     TOTAL > 1:
#         Bacteria:Actinobacteria:Coriobacteriia:Coriobacteriales:Coriobacteriaceae:Collinsella:Collinsella_aerofaciens ≤ 0.00884956:
#             Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Sutterellaceae:Parasutterella:Parasutterella_secunda ≤ 0.00574713:
#                 Bacteria:Actinobacteria:Coriobacteriia:Coriobacteriales:Coriobacteriaceae:Collinsella:Collinsella_aerofaciens ≤ 0:
#                     age ≤ 26: [1. 0. 2. 2. 2.]
#                     age > 26:
#                         Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ 0.0227273: [0. 2. 1. 0. 3.]
#                         Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > 0.0227273:
#                             TOTAL ≤ 1:
#                                 Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ 0.0438596:
#                                     Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ 0.0283688: [0. 2. 1. 3. 0.]
#                                     Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > 0.0283688: [1. 3. 2. 0. 0.]
#                                 Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > 0.0438596: [0. 0. 3. 2. 1.]
#                             TOTAL > 1: [0. 3. 0. 1. 1.]
#                 Bacteria:Actinobacteria:Coriobacteriia:Coriobacteriales:Coriobacteriaceae:Collinsella:Collinsella_aerofaciens > 0: [0. 1. 5. 0. 0.]
#             Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Sutterellaceae:Parasutterella:Parasutterella_secunda > 0.00574713: [2. 1. 0. 2. 0.]
#         Bacteria:Actinobacteria:Coriobacteriia:Coriobacteriales:Coriobacteriaceae:Collinsella:Collinsella_aerofaciens > 0.00884956: [0. 0. 0. 2. 3.]
# Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Roseburia:Roseburia_hominis > 0: [3. 0. 0. 3. 0.]
#
# ------------------------------------------------------------------------------------
# Decision tree for Participant+ExpressionDifference
# Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ 0.00610476:
#     Bacteria:Firmicutes:Bacilli:Lactobacillales:Streptococcaceae:Streptococcus:Streptococcus_pyogenes ≤ 0.00568182:
#         Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ -0.0108669:
#             Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ -0.0297619: [4. 1.]
#             Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > -0.0297619: [3. 4.]
#         Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > -0.0108669:
#             Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ -0.00263158: [5. 0.]
#             Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > -0.00263158: [4. 2.]
#     Bacteria:Firmicutes:Bacilli:Lactobacillales:Streptococcaceae:Streptococcus:Streptococcus_pyogenes > 0.00568182: [1. 4.]
# Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > 0.00610476:
#     Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 ≤ 0.0295795: [1. 6.]
#     Bacteria:Actinobacteria:Actinobacteria:Streptomycetales:Streptomycetaceae:Streptomyces:Streptomyces_sp._NRRL_F-6677 > 0.0295795: [2. 3.]
#
# ------------------------------------------------------------------------------------

# %% [markdown]
# ### Feature ranking
#
# Feature ranking quantifies the above process, by assigning a numerical importance score to each of the descriptive (expression) features. We calculated rankings based on several approaches, i.e., Information Gain Ratio, Gini Decrease and ReliefF.

# %%
from Orange.preprocess.score import GainRatio, Gini, ReliefF

gain_ratio = GainRatio()
gini = Gini()
relieff = ReliefF()

#table_agg._compute_contingency()

RANKERS = [("Information Gain Ratio", gain_ratio), ("Gini Decrease", gini), ("ReliefF", relieff)]

for table_name, table in DATASETS:
    print("------------------------------------------------------------------------------------")
    for ranker_name, ranker in RANKERS:
        scores = ranker(table_ends)
        
        print(f"Top 10 features for {table_name} using {ranker_name}:")
        for i, (score, attr) in enumerate(sorted(zip(scores, table_ends.domain.attributes), key=lambda x: x[0], reverse=True)[:10]):
            print(f"{i+1:2d}\t{score:.5f}\t{attr.name}")
        print()
# Out:
# ------------------------------------------------------------------------------------
# Top 10 features for Participant+ExpressionEndpoints using Information Gain Ratio:
#  1	0.33683	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_nordii
#  2	0.31074	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_coprocola
#  3	0.31074	Bacteria:Firmicutes:Clostridia:Clostridiales:Oscillospiraceae:Marseillibacter:Marseillibacter_massiliensis
#  4	0.29510	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_massiliensis
#  5	0.29289	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Rikenellaceae:Alistipes:Alistipes_shahii
#  6	0.29289	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Rikenellaceae:Alistipes:Alistipes_finegoldii
#  7	0.29230	Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Roseburia:Roseburia_hominis
#  8	0.29104	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Porphyromonadaceae:Gabonibacter:Gabonibacter_massiliensis
#  9	0.29104	Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Merdibacter:Merdibacter_massiliensis
# 10	0.29104	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Prevotellaceae:Prevotella:Prevotella_stercorea
#
# Top 10 features for Participant+ExpressionEndpoints using Gini Decrease:
#  1	0.03915	Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Roseburia:Roseburia_hominis
#  2	0.03662	Bacteria:Proteobacteria:Gammaproteobacteria:Pseudomonadales:Pseudomonadaceae:Pseudomonas:Pseudomonas_moraviensis
#  3	0.03229	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_coprocola
#  4	0.03229	Bacteria:Firmicutes:Clostridia:Clostridiales:Oscillospiraceae:Marseillibacter:Marseillibacter_massiliensis
#  5	0.03063	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Tannerellaceae:Parabacteroides:Parabacteroides_distasonis
#  6	0.03063	Bacteria:Firmicutes:Clostridia:Clostridiales:Clostridiaceae:Clostridium:Clostridium_sp._826
#  7	0.02872	Bacteria:Firmicutes:Clostridia:Clostridiales:Ruminococcaceae:Ruminococcus:Ruminococcus_bromii
#  8	0.02737	Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Sutterellaceae:Parasutterella:Parasutterella_secunda
#  9	0.02433	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Rikenellaceae:Alistipes:Alistipes_shahii
# 10	0.02433	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Rikenellaceae:Alistipes:Alistipes_finegoldii
#
# Top 10 features for Participant+ExpressionEndpoints using ReliefF:
#  1	0.00869	Bacteria:Firmicutes:Clostridia:Clostridiales:Oscillospiraceae:Oscillibacter:Oscillibacter_sp._ER4
#  2	0.00750	Bacteria:Firmicutes:Clostridia:Clostridiales:Clostridiaceae:Clostridium:Clostridium_sp._AT4
#  3	0.00450	Bacteria:Firmicutes:Bacilli:Lactobacillales:Streptococcaceae:Lactococcus:Lactococcus_lactis
#  4	0.00352	Bacteria:Firmicutes:Clostridia:Clostridiales:Clostridiaceae:Clostridium:Clostridium_sp._826
#  5	0.00300	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_nordii
#  6	0.00250	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Rikenellaceae:Alistipes:Alistipes_sp._AL-1
#  7	0.00250	Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Sutterellaceae:Sutterella:Sutterella_wadsworthensis
#  8	0.00250	Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Holdemania:Holdemania_massiliensis
#  9	0.00204	Bacteria:Firmicutes:Clostridia:Clostridiales:Clostridiaceae:Butyricicoccus:Butyricicoccus_pullicaecorum
# 10	0.00150	Archaea:Euryarchaeota:Methanobacteria:Methanobacteriales:Methanobacteriaceae:Methanobrevibacter:Methanobrevibacter_smithii
#
# ------------------------------------------------------------------------------------
# Top 10 features for Participant+ExpressionEndpoints+ExpressionAggregates using Information Gain Ratio:
#  1	0.33683	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_nordii
#  2	0.31074	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_coprocola
#  3	0.31074	Bacteria:Firmicutes:Clostridia:Clostridiales:Oscillospiraceae:Marseillibacter:Marseillibacter_massiliensis
#  4	0.29510	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_massiliensis
#  5	0.29289	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Rikenellaceae:Alistipes:Alistipes_shahii
#  6	0.29289	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Rikenellaceae:Alistipes:Alistipes_finegoldii
#  7	0.29230	Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Roseburia:Roseburia_hominis
#  8	0.29104	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Porphyromonadaceae:Gabonibacter:Gabonibacter_massiliensis
#  9	0.29104	Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Merdibacter:Merdibacter_massiliensis
# 10	0.29104	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Prevotellaceae:Prevotella:Prevotella_stercorea
#
# Top 10 features for Participant+ExpressionEndpoints+ExpressionAggregates using Gini Decrease:
#  1	0.03915	Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Roseburia:Roseburia_hominis
#  2	0.03662	Bacteria:Proteobacteria:Gammaproteobacteria:Pseudomonadales:Pseudomonadaceae:Pseudomonas:Pseudomonas_moraviensis
#  3	0.03229	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_coprocola
#  4	0.03229	Bacteria:Firmicutes:Clostridia:Clostridiales:Oscillospiraceae:Marseillibacter:Marseillibacter_massiliensis
#  5	0.03063	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Tannerellaceae:Parabacteroides:Parabacteroides_distasonis
#  6	0.03063	Bacteria:Firmicutes:Clostridia:Clostridiales:Clostridiaceae:Clostridium:Clostridium_sp._826
#  7	0.02872	Bacteria:Firmicutes:Clostridia:Clostridiales:Ruminococcaceae:Ruminococcus:Ruminococcus_bromii
#  8	0.02737	Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Sutterellaceae:Parasutterella:Parasutterella_secunda
#  9	0.02433	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Rikenellaceae:Alistipes:Alistipes_shahii
# 10	0.02433	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Rikenellaceae:Alistipes:Alistipes_finegoldii
#
# Top 10 features for Participant+ExpressionEndpoints+ExpressionAggregates using ReliefF:
#  1	0.01378	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_eggerthii
#  2	0.01252	Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Roseburia:Roseburia_hominis
#  3	0.01120	Bacteria:Proteobacteria:Gammaproteobacteria:Pseudomonadales:Pseudomonadaceae:Pseudomonas:Pseudomonas_moraviensis
#  4	0.00684	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_thetaiotaomicron
#  5	0.00679	Bacteria:Firmicutes:Clostridia:Clostridiales:Oscillospiraceae:Marseillibacter:Marseillibacter_massiliensis
#  6	0.00600	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_salyersiae
#  7	0.00524	Bacteria:Balneolaeota:Balneolia:Balneolales:Balneolaceae:Balneola:Balneola_sp._EhC07
#  8	0.00350	Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Erysipelatoclostridium:Erysipelatoclostridium_sp._SNUG30386
#  9	0.00350	Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Holdemania:Holdemania_massiliensis
# 10	0.00300	Bacteria:Firmicutes:Clostridia:Clostridiales:Ruminococcaceae:Negativibacillus:Negativibacillus_massiliensis
#
# ------------------------------------------------------------------------------------
# Top 10 features for Participant+ExpressionDifference using Information Gain Ratio:
#  1	0.33683	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_nordii
#  2	0.31074	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_coprocola
#  3	0.31074	Bacteria:Firmicutes:Clostridia:Clostridiales:Oscillospiraceae:Marseillibacter:Marseillibacter_massiliensis
#  4	0.29510	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_massiliensis
#  5	0.29289	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Rikenellaceae:Alistipes:Alistipes_shahii
#  6	0.29289	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Rikenellaceae:Alistipes:Alistipes_finegoldii
#  7	0.29230	Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Roseburia:Roseburia_hominis
#  8	0.29104	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Porphyromonadaceae:Gabonibacter:Gabonibacter_massiliensis
#  9	0.29104	Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Merdibacter:Merdibacter_massiliensis
# 10	0.29104	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Prevotellaceae:Prevotella:Prevotella_stercorea
#
# Top 10 features for Participant+ExpressionDifference using Gini Decrease:
#  1	0.03915	Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Roseburia:Roseburia_hominis
#  2	0.03662	Bacteria:Proteobacteria:Gammaproteobacteria:Pseudomonadales:Pseudomonadaceae:Pseudomonas:Pseudomonas_moraviensis
#  3	0.03229	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_coprocola
#  4	0.03229	Bacteria:Firmicutes:Clostridia:Clostridiales:Oscillospiraceae:Marseillibacter:Marseillibacter_massiliensis
#  5	0.03063	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Tannerellaceae:Parabacteroides:Parabacteroides_distasonis
#  6	0.03063	Bacteria:Firmicutes:Clostridia:Clostridiales:Clostridiaceae:Clostridium:Clostridium_sp._826
#  7	0.02872	Bacteria:Firmicutes:Clostridia:Clostridiales:Ruminococcaceae:Ruminococcus:Ruminococcus_bromii
#  8	0.02737	Bacteria:Proteobacteria:Betaproteobacteria:Burkholderiales:Sutterellaceae:Parasutterella:Parasutterella_secunda
#  9	0.02433	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Rikenellaceae:Alistipes:Alistipes_shahii
# 10	0.02433	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Rikenellaceae:Alistipes:Alistipes_finegoldii
#
# Top 10 features for Participant+ExpressionDifference using ReliefF:
#  1	0.01049	Bacteria:Firmicutes:Clostridia:Clostridiales:Lachnospiraceae:Roseburia:Roseburia_hominis
#  2	0.00734	Bacteria:Proteobacteria:Gammaproteobacteria:Pseudomonadales:Pseudomonadaceae:Pseudomonas:Pseudomonas_moraviensis
#  3	0.00700	Bacteria:Firmicutes:Clostridia:Clostridiales:Ruminococcaceae:Negativibacillus:Negativibacillus_massiliensis
#  4	0.00692	Bacteria:Firmicutes:Clostridia:Clostridiales:Oscillospiraceae:Marseillibacter:Marseillibacter_massiliensis
#  5	0.00576	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Tannerellaceae:Parabacteroides:Parabacteroides_distasonis
#  6	0.00554	Bacteria:Firmicutes:Negativicutes:Veillonellales:Veillonellaceae:Dialister:Dialister_succinatiphilus
#  7	0.00470	Bacteria:Verrucomicrobia:Verrucomicrobiae:Verrucomicrobiales:Akkermansiaceae:Akkermansia:Akkermansia_muciniphila
#  8	0.00450	Bacteria:Bacteroidetes:Bacteroidia:Bacteroidales:Bacteroidaceae:Bacteroides:Bacteroides_nordii
#  9	0.00450	Bacteria:Firmicutes:Erysipelotrichia:Erysipelotrichales:Erysipelotrichaceae:Holdemania:Holdemania_massiliensis
# 10	0.00400	Bacteria:Fusobacteria:Fusobacteriia:Fusobacteriales:Leptotrichiaceae:Sneathia:Sneathia_amnii
